# %%
import pandas as pd
import uteis

# %%
root = str(uteis.openfile())
print (root)
df = pd.read_excel(root)
# Out:
# C:/Projetos/Mercados/Trading_System/Database/ExperimentosParametros/ResumenExperimentos1H(03-10-22) - Periodo1.xlsx

# %%
arq = (root.split('/')[-1])
print(arq)
tic = (arq.split('-')[0])[-2:]
print (tic)
# Out:
# ResumenExperimentos1H(03-10-22) - Periodo1.xlsx
# 03

# %%
display(df.head())
# Out:
#          symbol            fechaIni            fechaFin   k  d  smoth  \
# 0  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  4      8
# 1  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  8      8
# 2  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      8
# 3  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      7
# 4  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  7      8
#
#    day mult  sem mult  cantSeñales  long index  maxLongAcu  minLongAcu  \
# 0         7         4           42    2.046586    2.260993    1.000000
# 1         6         4           66    2.105775    2.620268    1.000000
# 2         8         4           31    1.404933    1.768011    0.904328
# 3         8         4           36    1.468083    1.768012    0.904328
# 4         6         4           65    1.847181    2.392216    1.000000
#
#     minLong  short index  maxShortAcu  minShortAcu  minShort  long+short  \
# 0  0.869670     1.474895     2.022839      0.92812  0.854369    3.018499
# 1  0.797189     1.430186     1.772597      0.92812  0.729080    3.011649
# 2  0.838850     2.089928     2.403629      0.92812  0.912109    2.936208
# 3  0.857648     1.961838     2.367810      0.92812  0.897757    2.880140
# 4  0.851459     1.446676     1.775212      0.92812  0.723794    2.672273
#
#      maxInd   minInd
# 0  3.692784  0.92812
# 1  4.070572  0.92812
# 2  3.521681  0.92812
# 3  3.668538  0.92812
# 4  3.728222  0.92812

# %%
#display(df.describe)

# %%
display(df.dtypes)
# Out:
# symbol                 object
# fechaIni       datetime64[ns]
# fechaFin       datetime64[ns]
# k                       int64
# d                       int64
# smoth                   int64
# day mult                int64
# sem mult                int64
# cantSeñales             int64
# long index            float64
# maxLongAcu            float64
# minLongAcu            float64
# minLong               float64
# short index           float64
# maxShortAcu           float64
# minShortAcu           float64
# minShort              float64
# long+short            float64
# maxInd                float64
# minInd                float64
# dtype: object

# %%
display(df.columns)
# Out:
# Index(['symbol', 'fechaIni', 'fechaFin', 'k', 'd', 'smoth', 'day mult',
#        'sem mult', 'cantSeñales', 'long index', 'maxLongAcu', 'minLongAcu',
#        'minLong', 'short index', 'maxShortAcu', 'minShortAcu', 'minShort',
#        'long+short', 'maxInd', 'minInd'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotar gráfico de linha com seaborn
sns.lineplot(data=df, x='k', y ='long index' )
plt.xlabel('k')
plt.ylabel('long index')
plt.yscale('linear')
plt.title(df.iloc[1]['symbol'])
plt.show()

# %%
# Plotar gráfico de linha com seaborn
sns.lineplot(data=df, x='d', y ='long index' )
plt.xlabel('d')
plt.ylabel('long index')
plt.yscale('linear')
plt.title(df.iloc[1]['symbol'])
plt.show()

# %%
sns.lineplot(data=df, x='smoth', y ='long index' )
plt.xlabel('smoth')
plt.ylabel('long index')
plt.yscale('linear')
plt.title(df.iloc[1]['symbol'])
plt.show()

# %%
sns.lineplot(data=df, x='day mult', y ='long index' )
plt.xlabel('day mult')
plt.ylabel('long index')
plt.yscale('linear')
plt.title(df.iloc[1]['symbol'])
plt.show()

# %%
sns.lineplot(data=df, x='sem mult', y ='long index' )
plt.xlabel('sem mult')
plt.ylabel('long index')
plt.yscale('linear')
plt.title(df.iloc[1]['symbol'])
plt.show()

# %%
dfgraf = df[['k','d','smoth','day mult','sem mult','long index']]
display (dfgraf.head(10))
# Out:
#     k  d  smoth  day mult  sem mult  long index
# 0  17  4      8         7         4    2.046586
# 1  12  8      8         6         4    2.105775
# 2  17  8      8         8         4    1.404933
# 3  17  8      7         8         4    1.468083
# 4  12  7      8         6         4    1.847181
# 5  17  7      8         8         4    1.329898
# 6  18  6      8         8         4    1.313008
# 7  18  8      7         8         4    1.306424
# 8  17  6      8         8         4    1.453892
# 9  18  7      8         8         4    1.277659

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



# Plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with k, d, smoth as coordinates
scatter = ax.scatter(dfgraf['k'], dfgraf['d'], dfgraf['smoth'], c=dfgraf['long index'], s=dfgraf['day mult']*10, cmap='viridis')

ax.set_xlabel('k')
ax.set_ylabel('d')
ax.set_zlabel('smoth')
ax.set_title('3D Scatter Plot of Discrete Scalar Function')

# Adding colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Scalar function (long index)')

plt.show()

# %%
dftb_exp = df.copy()
dftb_exp.insert(0,'Arquiv',arq)
dftb_exp.insert(2,'Tic',tic)

dftb_exp.insert(2,'TrdSys',dftb_exp['symbol'].str.split('-', expand=True)[1])
dftb_exp['symbol'] = dftb_exp['symbol'].str.split('-', expand=True)[0]
dftb_exp.insert(0,'idExper',dftb_exp['symbol']+dftb_exp['TrdSys']+ dftb_exp['Tic'] + dftb_exp['k'].astype(str)+ dftb_exp['d'].astype(str)+ dftb_exp['smoth'].astype(str)+ dftb_exp['day mult'].astype(str)+ dftb_exp['sem mult'].astype(str)+ dftb_exp['fechaIni'].astype(str))

display(dftb_exp.head())
# Out:
#                                   idExper  \
# 0  GGAL_ADRST1031748742020-03-02 14:30:00
# 1  GGAL_ADRST1031288642020-03-02 14:30:00
# 2  GGAL_ADRST1031788842020-03-02 14:30:00
# 3  GGAL_ADRST1031787842020-03-02 14:30:00
# 4  GGAL_ADRST1031278642020-03-02 14:30:00
#
#                                             Arquiv    symbol TrdSys Tic  \
# 0  ResumenExperimentos1H(03-10-22) - Periodo1.xlsx  GGAL_ADR    ST1  03
# 1  ResumenExperimentos1H(03-10-22) - Periodo1.xlsx  GGAL_ADR    ST1  03
# 2  ResumenExperimentos1H(03-10-22) - Periodo1.xlsx  GGAL_ADR    ST1  03
# 3  ResumenExperimentos1H(03-10-22) - Periodo1.xlsx  GGAL_ADR    ST1  03
# 4  ResumenExperimentos1H(03-10-22) - Periodo1.xlsx  GGAL_ADR    ST1  03
#
#              fechaIni            fechaFin   k  d  smoth  day mult  sem mult  \
# 0 2020-03-02 14:30:00 2022-04-05 19:30:00  17  4      8         7         4
# 1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  8      8         6         4
# 2 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      8         8         4
# 3 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      7         8         4
# 4 2020-03-02 14:30:00 2022-04-05 19:30:00  12  7      8         6         4
#
#    cantSeñales  long index  maxLongAcu  minLongAcu   minLong  short index  \
# 0           42    2.046586    2.260993    1.000000  0.869670     1.474895
# 1           66    2.105775    2.620268    1.000000  0.797189     1.430186
# 2           31    1.404933    1.768011    0.904328  0.838850     2.089928
# 3           36    1.468083    1.768012    0.904328  0.857648     1.961838
# 4           65    1.847181    2.392216    1.000000  0.851459     1.446676
#
#    maxShortAcu  minShortAcu  minShort  long+short    maxInd   minInd
# 0     2.022839      0.92812  0.854369    3.018499  3.692784  0.92812
# 1     1.772597      0.92812  0.729080    3.011649  4.070572  0.92812
# 2     2.403629      0.92812  0.912109    2.936208  3.521681  0.92812
# 3     2.367810      0.92812  0.897757    2.880140  3.668538  0.92812
# 4     1.775212      0.92812  0.723794    2.672273  3.728222  0.92812

# %%
import sqlite3
# Conecte-se ao banco de dados (ou crie um novo arquivo de banco de dados)
conexao = sqlite3.connect('dbExperimentos.db')
# Exportar o DataFrame para uma tabela no banco de dados SQLite
dftb_exp.to_sql('dbtb_experimento', conexao, if_exists='append', index=False)
# Fechar a conexão
conexao.close()

# %%
# Conectar ao banco de dados SQLite
conn = sqlite3.connect('dbExperimentos.db')
#conn.execute("DROP VIEW IF EXISTS sqArquivos")
# Ler a tabela para um DataFrame do pandas
sqArquivos = pd.read_sql('SELECT * from sqArquivos', conn)
# Fechar a conexão
conn.close()
#pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
#sqArquivos = df.style.set_properties(**{'text-align': 'left'})
# Mostrar o DataFrame
display (sqArquivos)
# Out:
#                                                         Arquiv  Files
# 0           ResumenExperimentos15min(03-10-22) - Periodo1.xlsx   1536
# 1           ResumenExperimentos15min(03-10-22) - Periodo2.xlsx   1536
# 2     ResumenExperimentos15min(03-11-22)(Est2) - Periodo1.xlsx   1536
# 3     ResumenExperimentos15min(03-11-22)(Est2) - Periodo2.xlsx   1536
# 4      ResumenExperimentos15min_EST2(08-11-22) - Periodo1.xlsx   1536
# 5      ResumenExperimentos15min_EST2(08-11-22) - Periodo2.xlsx   1536
# 6              ResumenExperimentos1H(03-10-22) - Periodo1.xlsx   2520
# 7              ResumenExperimentos1H(03-10-22) - Periodo2.xlsx   2520
# 8          ResumenExperimentos1H-EEM(18-10-22) - Periodo1.xlsx   2520
# 9          ResumenExperimentos1H-EEM(18-10-22) - Periodo2.xlsx   2520
# 10  ResumenExperimentos1H-GGAL(02-11-22)(Est2) - Periodo1.xlsx   2520
# 11        ResumenExperimentos1H-GGAL(18-10-22) - Periodo1.xlsx   2520
# 12        ResumenExperimentos1H-GGAL(18-10-22) - Periodo2.xlsx   2520
# 13   ResumenExperimentos1H-GGAL(Com)(02-11-22) - Periodo1.xlsx   2520
# 14   ResumenExperimentos1H-GGAL(Com)(02-11-22) - Periodo2.xlsx   2520
# 15   ResumenExperimentos1H-GGAL_EST2(08-11-22) - Periodo1.xlsx   2520
# 16   ResumenExperimentos1H-GGAL_EST2(08-11-22) - Periodo2.xlsx   2520
# 17      ResumenExperimentos1H-IMVUSD(18-10-22) - Periodo1.xlsx   2520
# 18      ResumenExperimentos1H-IMVUSD(18-10-22) - Periodo2.xlsx   2520
# 19         ResumenExperimentos1H-SPX(18-10-22) - Periodo1.xlsx   2520
# 20         ResumenExperimentos1H-SPX(18-10-22) - Periodo2.xlsx   2520
# 21           ResumenExperimentos2min(03-10-22) - Periodo1.xlsx   1280
# 22           ResumenExperimentos2min(03-10-22) - Periodo2.xlsx   1280
