# %%
pip install dash plotly pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Projetos/Mercados/Trading_System/Database/ExperimentosParametros/ResumenExperimentos1H(03-10-22) - Periodo1.xlsx')
display (df.head())
# Out:
#          symbol            fechaIni            fechaFin   k  d  smoth  \
# 0  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  4      8
# 1  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  8      8
# 2  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      8
# 3  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  8      7
# 4  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  7      8
#
#    day mult  sem mult  cantSeñales  long index  maxLongAcu  minLongAcu  \
# 0         7         4           42    2.046586    2.260993    1.000000
# 1         6         4           66    2.105775    2.620268    1.000000
# 2         8         4           31    1.404933    1.768011    0.904328
# 3         8         4           36    1.468083    1.768012    0.904328
# 4         6         4           65    1.847181    2.392216    1.000000
#
#     minLong  short index  maxShortAcu  minShortAcu  minShort  long+short  \
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd

#long2 = df.query('longindex >= 2')
long2 = df[df['long index'] > 2 ]
display (long2.head())

# Create a bar chart
bar_chart = px.bar(df, x=df['long index']  , y=  df['k'] , title='Bar Chart Example')

# Create a line chart
line_chart = px.line(df, x=df['long index']  , y=  df['k'], title='Line Chart Example')

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the app layout
app.layout = html.Div(children=[
    html.H1(children='Basic Dashboard'),

    html.Div(children='''
        Dash: A web application framework for Python.
    '''),

    dcc.Graph(
        id='bar-chart',
        figure=bar_chart
    ),

    dcc.Graph(
        id='line-chart',
        figure=line_chart
    )
])

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\scitr\AppData\Local\Temp\ipykernel_7488\1031465232.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\scitr\AppData\Local\Temp\ipykernel_7488\1031465232.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
#           symbol            fechaIni            fechaFin   k  d  smoth  \
# 0   GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  4      8
# 1   GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  12  8      8
# 17  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  17  4      7
# 30  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  16  4      7
# 40  GGAL_ADR-ST1 2020-03-02 14:30:00 2022-04-05 19:30:00  18  4      7
#
# ...

# %%
python app.py
# Out:
#   Cell In[11], line 1
#     python app.py
#            ^
# SyntaxError: invalid syntax
