# %% [markdown]
# Back Testing

# %%
from datetime import date, datetime
import pandas as pd
import yfinance as yf
import time
from Alert import Alert
pd.options.mode.chained_assignment = None  # default='warn'
alert = Alert('1h','GGAL')

# %%
input:
    
     Titulo  : example: GGAL
     frequencia de tick : 1h (frequencia mais alta)
     dftitulo : vista do BD sqtitulosalpha.bd (testar ultimos periodas)
Parametros a variar para back testing ( definir rangos de variação)
     k, d, smooth (parametros do stch)
     dayM  (frequencia media) (multiplicador da frequencia mais alta) exemplo: 5
     semM  (frequencia baixa) (multiplicador da frequencia media) exemplo: 7

# %%
dataini = '2020-04-03 19:30:00'
datafim = '2023-04-03 19:30:00'

# %%
import sqlite3
import pandas as pd

# Caminho para o banco de dados
caminho_bd = r'C:\Users\scitr\anaconda_projects\Trading_System\Dados_Fontes\Alpha_Vantage\sqtitulosalpha.db'

# Conectando ao banco
conexao = sqlite3.connect(caminho_bd)

# Lendo a view
#consulta = 'SELECT * FROM vwtitulosdados ORDER BY datetime'
consulta = f"""
SELECT * FROM vwtitulosdados
WHERE datetime BETWEEN '{dataini}' AND '{datafim}'
ORDER BY datetime
"""

dftitulosdados = pd.read_sql_query(consulta, conexao)

# Fechando a conexão
conexao.close()

# Exibindo os primeiros registros para conferir
display(dftitulosdados)
# Out:
#      symbol moeda intervalo             datetime    open    high     low  \
# 0      GGAL   USD     60min  2020-04-06 08:00:00  5.8034  5.8034  5.8034
# 1      GGAL   USD     60min  2020-04-06 09:00:00  6.0432  6.2510  5.9952
# 2      GGAL   USD     60min  2020-04-06 10:00:00  6.0945  6.0945  5.6635
# 3      GGAL   USD     60min  2020-04-06 11:00:00  5.7954  5.8034  5.4837
# 4      GGAL   USD     60min  2020-04-06 12:00:00  5.6715  5.8354  5.6355
# ...     ...   ...       ...                  ...     ...     ...     ...
# 6578   GGAL   USD     60min  2023-04-03 12:00:00  9.5499  9.6357  9.5499
# 6579   GGAL   USD     60min  2023-04-03 13:00:00  9.5671  9.6872  9.5671
# 6580   GGAL   USD     60min  2023-04-03 14:00:00  9.6785  9.7447  9.6529
# 6581   GGAL   USD     60min  2023-04-03 15:00:00  9.7386  9.7816  9.6529
# 6582   GGAL   USD     60min  2023-04-03 16:00:00  9.7472  9.7472  9.7472
#
#        close    volume
# 0     5.8034     100.0
# 1     6.0832  114582.0
# 2     5.7954  159266.0
# 3     5.6835  242263.0
# 4     5.8274  186504.0
# ...      ...       ...
# 6578  9.5756   29258.0
# 6579  9.6700   48527.0
# 6580  9.7301   32877.0
# 6581  9.7558  143309.0
# 6582  9.7472   13155.0
#
# [6583 rows x 9 columns]

# %%
i = '1h'
K = 16  
D = 5    
smoth = 5  
dayM = 8  
semM = 4

# %%
# Stochastic calculation
def stochastic(df, i, K, D, smoth):
        
    df["k"] = (100. * (df.close - df.low.rolling(K).min()) /
        (df.high.rolling(K).max() - df.low.rolling(K).min()))
    
    df["k" + i] = df.k.rolling(smoth).mean()
    df["d" + i] = df["k" + i].rolling(D).mean()
    
    df.drop(columns=["k"], inplace=True)  

    return df
dfstoch = stochastic(dftitulosdados, i, K, D, smoth)
display (dfstoch)
# Out:
#      symbol moeda intervalo             datetime    open    high     low  \
# 0      GGAL   USD     60min  2020-04-06 08:00:00  5.8034  5.8034  5.8034
# 1      GGAL   USD     60min  2020-04-06 09:00:00  6.0432  6.2510  5.9952
# 2      GGAL   USD     60min  2020-04-06 10:00:00  6.0945  6.0945  5.6635
# 3      GGAL   USD     60min  2020-04-06 11:00:00  5.7954  5.8034  5.4837
# 4      GGAL   USD     60min  2020-04-06 12:00:00  5.6715  5.8354  5.6355
# ...     ...   ...       ...                  ...     ...     ...     ...
# 6578   GGAL   USD     60min  2023-04-03 12:00:00  9.5499  9.6357  9.5499
# 6579   GGAL   USD     60min  2023-04-03 13:00:00  9.5671  9.6872  9.5671
# 6580   GGAL   USD     60min  2023-04-03 14:00:00  9.6785  9.7447  9.6529
# 6581   GGAL   USD     60min  2023-04-03 15:00:00  9.7386  9.7816  9.6529
# 6582   GGAL   USD     60min  2023-04-03 16:00:00  9.7472  9.7472  9.7472
#
#        close    volume        k1h        d1h
# 0     5.8034     100.0        NaN        NaN
# 1     6.0832  114582.0        NaN        NaN
# 2     5.7954  159266.0        NaN        NaN
# 3     5.6835  242263.0        NaN        NaN
# 4     5.8274  186504.0        NaN        NaN
# ...      ...       ...        ...        ...
# 6578  9.5756   29258.0  35.345039  24.486408
# 6579  9.6700   48527.0  43.814248  30.270650
# 6580  9.7301   32877.0  53.958531  37.149336
# 6581  9.7558  143309.0  64.423364  45.395125
# 6582  9.7472   13155.0  69.770972  53.462431
#
# [6583 rows x 11 columns]

# %%
def set_test( df, intervalo, k, d, smth, dayM, semM):
        
        # Convert time
        #df["time"] = pd.to_datetime(df.index, utc=True)
        #df['timeArg'] = df['time'].dt.tz_convert('America/Argentina/Buenos_Aires')        
        #df['time'] = df['time'].dt.tz_convert(None)

        df = stochastic(df, "hora", k, d, smth)
        df = stochastic(df, "dia", k*dayM, d*dayM, smth*dayM)
        df = stochastic(df, "sem", k*dayM*semM, d*dayM*semM, smth*dayM*semM)
    
        return df
dfstochhlc= set_test(dfstoch, i , K, D, smoth, dayM , semM )
display(dfstochhlc )
# %time set_test(dfstoch, i , K, D, smoth, dayM , semM )
# Out:
#      symbol moeda intervalo             datetime    open    high     low  \
# 0      GGAL   USD     60min  2020-04-06 08:00:00  5.8034  5.8034  5.8034
# 1      GGAL   USD     60min  2020-04-06 09:00:00  6.0432  6.2510  5.9952
# 2      GGAL   USD     60min  2020-04-06 10:00:00  6.0945  6.0945  5.6635
# 3      GGAL   USD     60min  2020-04-06 11:00:00  5.7954  5.8034  5.4837
# 4      GGAL   USD     60min  2020-04-06 12:00:00  5.6715  5.8354  5.6355
# ...     ...   ...       ...                  ...     ...     ...     ...
# 6578   GGAL   USD     60min  2023-04-03 12:00:00  9.5499  9.6357  9.5499
# 6579   GGAL   USD     60min  2023-04-03 13:00:00  9.5671  9.6872  9.5671
# 6580   GGAL   USD     60min  2023-04-03 14:00:00  9.6785  9.7447  9.6529
# 6581   GGAL   USD     60min  2023-04-03 15:00:00  9.7386  9.7816  9.6529
# 6582   GGAL   USD     60min  2023-04-03 16:00:00  9.7472  9.7472  9.7472
#
#        close    volume        k1h        d1h      khora      dhora       kdia  \
# 0     5.8034     100.0        NaN        NaN        NaN        NaN        NaN
# 1     6.0832  114582.0        NaN        NaN        NaN        NaN        NaN
# 2     5.7954  159266.0        NaN        NaN        NaN        NaN        NaN
# 3     5.6835  242263.0        NaN        NaN        NaN        NaN        NaN
# 4     5.8274  186504.0        NaN        NaN        NaN        NaN        NaN
# ...      ...       ...        ...        ...        ...        ...        ...
# 6578  9.5756   29258.0  35.345039  24.486408  35.345039  24.486408  45.055766
# 6579  9.6700   48527.0  43.814248  30.270650  43.814248  30.270650  45.854905
# 6580  9.7301   32877.0  53.958531  37.149336  53.958531  37.149336  46.699935
# 6581  9.7558  143309.0  64.423364  45.395125  64.423364  45.395125  47.601915
# 6582  9.7472   13155.0  69.770972  53.462431  69.770972  53.462431  48.490496
#
#            ddia       ksem       dsem
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 6578  33.328487  48.012866  70.547223
# 6579  33.918139  47.710336  70.311149
# 6580  34.512110  47.428408  70.073438
# 6581  35.110265  47.142843  69.834096
# 6582  35.712189  46.851390  69.593059
#
# [6583 rows x 17 columns]
# CPU times: total: 31.2 ms
# Wall time: 34.3 ms
#      symbol moeda intervalo             datetime    open    high     low  \
# 0      GGAL   USD     60min  2020-04-06 08:00:00  5.8034  5.8034  5.8034
# 1      GGAL   USD     60min  2020-04-06 09:00:00  6.0432  6.2510  5.9952
# 2      GGAL   USD     60min  2020-04-06 10:00:00  6.0945  6.0945  5.6635
# 3      GGAL   USD     60min  2020-04-06 11:00:00  5.7954  5.8034  5.4837
# 4      GGAL   USD     60min  2020-04-06 12:00:00  5.6715  5.8354  5.6355
# ...     ...   ...       ...                  ...     ...     ...     ...
# 6578   GGAL   USD     60min  2023-04-03 12:00:00  9.5499  9.6357  9.5499
# 6579   GGAL   USD     60min  2023-04-03 13:00:00  9.5671  9.6872  9.5671
# 6580   GGAL   USD     60min  2023-04-03 14:00:00  9.6785  9.7447  9.6529
# 6581   GGAL   USD     60min  2023-04-03 15:00:00  9.7386  9.7816  9.6529
# 6582   GGAL   USD     60min  2023-04-03 16:00:00  9.7472  9.7472  9.7472
#
#        close    volume        k1h        d1h      khora      dhora       kdia  \
# 0     5.8034     100.0        NaN        NaN        NaN        NaN        NaN
# 1     6.0832  114582.0        NaN        NaN        NaN        NaN        NaN
# 2     5.7954  159266.0        NaN        NaN        NaN        NaN        NaN
# 3     5.6835  242263.0        NaN        NaN        NaN        NaN        NaN
# 4     5.8274  186504.0        NaN        NaN        NaN        NaN        NaN
# ...      ...       ...        ...        ...        ...        ...        ...
# 6578  9.5756   29258.0  35.345039  24.486408  35.345039  24.486408  45.055766
# 6579  9.6700   48527.0  43.814248  30.270650  43.814248  30.270650  45.854905
# 6580  9.7301   32877.0  53.958531  37.149336  53.958531  37.149336  46.699935
# 6581  9.7558  143309.0  64.423364  45.395125  64.423364  45.395125  47.601915
# 6582  9.7472   13155.0  69.770972  53.462431  69.770972  53.462431  48.490496
#
#            ddia       ksem       dsem
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 6578  33.328487  48.012866  70.547223
# 6579  33.918139  47.710336  70.311149
# 6580  34.512110  47.428408  70.073438
# 6581  35.110265  47.142843  69.834096
# 6582  35.712189  46.851390  69.593059
#
# [6583 rows x 17 columns]

# %%
#insere  'COMPRA' no campo oper do df no registro i 
def set_compra( df, i):
        df.loc[i, "oper"] = "COMPRA"
    
#insere  'VENTA' no campo oper do df no registro i 
def set_venta( df, i):
        df.loc[i, "oper"] = "VENTA"


def close_long( df, i, compra, venta):
        df.loc[i, "oper"] = "CLOSELONG"
        if compra !=0.:
            df.loc[i, "long"] = (venta - compra) / compra


def close_short( df, i, compra, venta):
        df.loc[i, "oper"] = "CLOSESHORT"
        if venta !=0.:
            df.loc[i, "short"] = (venta - compra) / venta

# %%
def set_signals(df):
        state = ""
        df["compra"] = False
        df["venta"] = False
        df["closeLong"] = False
        df["closeShort"] = False
        df["entradaLongH"] = False
        df["entradaShortH"] = False
        df["oper"] = ""
        df["long"] = ""
        df["short"] = ""
        df["state"] = "neutro"

        compra = 0.
        venta = 0.
#alert.py part 2
        
# outros intervalos
        lastEntradaLongH = False
        lastEntradaShortH = False
            
        for i in df.index:      
            l = df.loc[i]
            df.loc[i, "state"] = state

        #for i, l in df.iterrows():
            #df.at[i, "state"] = state
            khora = float(l.khora)
            dhora = float(l.dhora)
            kdia = float(l.kdia)
            ddia = float(l.ddia)
            ksem = float(l.ksem)
            dsem = float(l.dsem)
            
            if (khora > 20) and (khora > dhora):                   # "si stoch high EM CONDIÇÃO DE COMPRA          
                    df.at[i, "entradaLongH"] = True     
        
                # ESTRATEGIA 1 - Stochastico alineado y esperar cruce
                #if (l.khora > 20. and l.khora > l.dhora):
                    #df.loc[i, "entradaLongH"] = True
                    if (not lastEntradaLongH):                       # si  la entradalong anterior es true  
                        if (kdia > 20. and kdia > ddia):                 # si stch midfre em condição de compra
                            if(state == "venta"):                           # si estabamos en short 
                                df.loc[i, "closeShort"] = True                 # fechamos short
                                state = "neutro"                               # mudamos estado a neutro
                                compra = l.close                               
                                close_short(df, i, compra, venta)              # calcula ganancia porcentual y coloca na coluna short
                            if (ksem > 80. or ksem > dsem):                  #stch lowfre acima media d ou acima de 80 , para evitar saida anticipada
                                df.loc[i, "compra"] = True                       # compramos long                  
                                if state != "compra":                             # si no tenihamos comprado
                                    state = "compra"                                 # mudamos estado a compra
                                    compra = l.close                                 
                                    set_compra(df, i)                                # mudamos oper a COMPRA
            else:
                df.loc[i, "entradaLongH"] = False                   # si no esta  em condição de compra 

            if (l.khora < 80. and l.khora < l.dhora):
                    df.loc[i, "entradaShortH"] = True
                    if (not lastEntradaShortH):
                        if(l.kdia < 80. and l.kdia < l.ddia):
                            if(state == "compra"):
                                df.loc[i, "closeLong"] = True
                                state = "neutro"
                                venta = l.close
                                close_long(df, i, compra, venta)
                            if(l.ksem < 20. or l.ksem < l.dsem):
                                df.loc[i, "venta"] = True
                                if state != "venta":
                                    state = "venta"
                                    venta = l.close
                                    set_venta(df, i)
            else:
                    df.loc[i, "entradaShortH"] = False

            lastEntradaLongH = df.loc[i, "entradaLongH"]
            lastEntradaShortH = df.loc[i, "entradaShortH"]
                    
        
        return df
    
dfsignal= set_signals(dfstochhlc)          
#display(dfsignal)

# %%
#df_filtrado = dfsignal[dfsignal['compra'].notna() | dfsignal['venta'].notna()]
#df_filtrado = dfsignal[dfsignal['state'].notna()]
df_filtrado = dfsignal[(dfsignal['state'].notna()) & (dfsignal['state'] == 'venta')]
#df_filtrado = dfsignal[dfsignal['compra'] == True]
df_filtrado = dfsignal[dfsignal['oper'] != '']

pd.set_option('display.max_rows', None)  # Mostra todas as linhas

print(f"Total de registros com 'state' preenchido: {len(df_filtrado)}")
display(df_filtrado.iloc[:, 11:])
# Out:
# Total de registros com 'state' preenchido: 87
#           khora      dhora       kdia       ddia       ksem       dsem  \
# 719   58.805532  54.782934  77.560404  69.456308  84.667712        NaN
# 767   56.570574  66.085405  66.369308  78.457399  86.460965        NaN
# 846    6.715225   6.755678  30.931970  48.482412  79.710350  84.534459
# 970   43.816521  43.814087  21.067897  12.366351  33.094373  62.534045
# 1060  51.218447  51.755551  24.412361  40.063877  15.071505  32.399684
# 1195  27.500680  17.702370  20.897295  17.598614   4.512878  10.439022
# 1258  13.224721  14.984595  25.773712  30.182975   4.880179   6.585868
# 1299  27.344972  15.490774  28.014453  23.058807   4.739077   5.355476
# 1325  59.038095  65.853663  25.329733  27.756764   4.365731   4.901127
# 1368  86.525592  86.279734  34.938730  25.590686   4.898888   4.620799
# 1459  72.435984  79.153232  79.224264  83.336733  26.703526   9.924836
# 1521  63.571611  62.461801  75.254779  74.311003  45.994521  22.341196
# 1594  32.264328  45.979869  74.517188  81.905040  66.096173  43.645044
# 1699  52.857762  51.492607  36.172250  33.800972  83.550640  70.847190
# 1745  47.970770  50.260151  32.978615  46.763865  80.334349  77.883162
# 1771  25.962928  27.996971  13.878475  26.934784  76.744760  79.761051
# 1873  62.494030  60.525532  21.583904  10.942217  58.010069  72.905157
# 1986  75.918055  82.515381  74.510173  75.405037  39.702871  51.050077
# 1996  67.026236  62.696431  78.609674  75.638443  40.295718  49.325586
# 2029  12.850684  17.712793  73.521941  80.744371  44.102230  45.162125
# 2158  81.038417  80.334915  23.144059  10.576499  27.380491  39.844754
# 2228  74.121017  77.864241  63.941543  69.807392  26.034093  31.525079
# 2316  25.724382  22.670074  32.092717  30.283210  36.159389  28.426327
# 2350  76.347946  76.586137  21.435346  29.225406  30.717154  30.265600
# 2478  60.067058  62.916389  29.952618  47.067776  17.595251  25.131625
# 2512  29.138545  27.671929  55.976029  36.399338  21.310451  22.045283
# 2522  22.314866  16.708310  63.822826  43.942568  22.879028  21.599748
# 2594  24.589182  25.346753  78.509835  83.328001  50.472288  27.744432
# 2630  83.586016  82.295569  74.907693  73.709935  63.934951  35.711149
# 2741  79.873711  80.623880  79.800686  84.383598  86.174426  72.729001
# 2809  48.595705  50.419036  27.137115  41.376530  81.407383  84.390744
# 5314   False  False       True       False         False           True
# 5336    True  False      False       False          True          False
# 5381   False  False       True       False         False           True
# 5402    True  False      False       False          True          False
# 5435   False  False       True       False         False           True
# 5515   False   True      False       False         False           True
# 5566   False  False      False        True          True          False
# 5585   False   True      False       False         False           True
# 5633   False  False      False        True          True          False
# 5749   False   True      False       False         False           True
# 5846   False  False      False        True          True          False
# 5917   False   True      False       False         False           True
# 5989    True  False      False        True          True          False
# 6172   False  False       True       False         False           True
# 6212    True  False      False       False          True          False
# 6228   False  False       True       False         False           True
# 6252   False   True      False       False         False           True
# 6307    True  False      False        True          True          False
# 6361   False   True       True       False         False           True
# 6390    True  False      False        True          True          False
# 6420   False  False       True       False         False           True
# 6460   False   True      False       False         False           True
# 6552   False  False      False        True          True          False
#
#             oper      long     short   state
# 719       COMPRA
# 767    CLOSELONG -0.069267            compra
# 846        VENTA                      neutro
# 970   CLOSESHORT            0.081937   venta
# 1060       VENTA                      neutro
# 1195  CLOSESHORT            0.199556   venta
# 1258       VENTA                      neutro
# 1299  CLOSESHORT           -0.029422   venta
# 1325       VENTA                      neutro
# 1368      COMPRA           -0.048343   venta
# 1459   CLOSELONG  0.190193            compra
# 1521      COMPRA                      neutro
# 1594   CLOSELONG -0.014733            compra
# 1699      COMPRA                      neutro
# 1745   CLOSELONG -0.069419            compra
# 1771       VENTA                      neutro
# 1873  CLOSESHORT            0.011395   venta
# 1986       VENTA                      neutro
# 1996  CLOSESHORT            -0.03975   venta
# 2029       VENTA                      neutro
# 2158  CLOSESHORT            0.021252   venta
# 2228       VENTA                      neutro
# 2316      COMPRA            0.021496   venta
# 2350   CLOSELONG -0.052963            compra
# 2478       VENTA                      neutro
# 2512  CLOSESHORT           -0.085764   venta
# 2522      COMPRA                      neutro
# 2594   CLOSELONG   0.05998            compra
# 2630      COMPRA                      neutro
# 2741   CLOSELONG  0.150907            compra
# 2809       VENTA                      neutro
# 2968  CLOSESHORT            0.100938   venta
# 3018       VENTA                      neutro
# 3045  CLOSESHORT           -0.068561   venta
# 3108       VENTA                      neutro
# 3157      COMPRA           -0.210576   venta
# 3287   CLOSELONG  0.079532            compra
# 3365       VENTA                      neutro
# 3409  CLOSESHORT           -0.091968   venta
# 3525      COMPRA                      neutro
# 3563   CLOSELONG -0.040249            compra
# 3609      COMPRA                      neutro
# 3660   CLOSELONG -0.002631            compra
# 3694       VENTA                      neutro
# 3788  CLOSESHORT            0.018269   venta
# 4000      COMPRA                      neutro
# 4029       VENTA -0.076055            compra
# 4080  CLOSESHORT           -0.023364   venta
# 4139      COMPRA                      neutro
# 4165   CLOSELONG -0.002148            compra
# 4225      COMPRA                      neutro
# 4261   CLOSELONG -0.004946            compra
# 4364      COMPRA                      neutro
# 4462   CLOSELONG  0.087652            compra
# 4555       VENTA                      neutro
# 4660  CLOSESHORT               0.076   venta
# 4704       VENTA                      neutro
# 4711  CLOSESHORT           -0.034163   venta
# 4774       VENTA                      neutro
# 4800      COMPRA           -0.032574   venta
# 4821   CLOSELONG -0.053625            compra
# 4900       VENTA                      neutro
# 5130  CLOSESHORT            0.086613   venta
# 5141      COMPRA                      neutro
# 5314   CLOSELONG  0.258941            compra
# 5336      COMPRA                      neutro
# 5381   CLOSELONG -0.018185            compra
# 5402      COMPRA                      neutro
# 5435   CLOSELONG  0.008051            compra
# 5515       VENTA                      neutro
# 5566  CLOSESHORT           -0.058511   venta
# 5585       VENTA                      neutro
# 5633  CLOSESHORT            0.006676   venta
# 5749       VENTA                      neutro
# 5846  CLOSESHORT           -0.003887   venta
# 5917       VENTA                      neutro
# 5989      COMPRA           -0.119745   venta
# 6172   CLOSELONG  0.584197            compra
# 6212      COMPRA                      neutro
# 6228   CLOSELONG -0.003843            compra
# 6252       VENTA                      neutro
# 6307      COMPRA           -0.149595   venta
# 6361       VENTA -0.042439            compra
# 6390      COMPRA            0.010484   venta
# 6420   CLOSELONG -0.058064            compra
# 6460       VENTA                      neutro
# 6552  CLOSESHORT           -0.032389   venta

# %%
# %time set_signals(dfstochhlc)
# Out:
# CPU times: total: 11 s
# Wall time: 11.3 s
#      symbol moeda intervalo             datetime    open    high     low  \
# 0      GGAL   USD     60min  2020-04-06 08:00:00  5.8034  5.8034  5.8034
# 1      GGAL   USD     60min  2020-04-06 09:00:00  6.0432  6.2510  5.9952
# 2      GGAL   USD     60min  2020-04-06 10:00:00  6.0945  6.0945  5.6635
# 3      GGAL   USD     60min  2020-04-06 11:00:00  5.7954  5.8034  5.4837
# 4      GGAL   USD     60min  2020-04-06 12:00:00  5.6715  5.8354  5.6355
# ...     ...   ...       ...                  ...     ...     ...     ...
# 6578   GGAL   USD     60min  2023-04-03 12:00:00  9.5499  9.6357  9.5499
# 6579   GGAL   USD     60min  2023-04-03 13:00:00  9.5671  9.6872  9.5671
# 6580   GGAL   USD     60min  2023-04-03 14:00:00  9.6785  9.7447  9.6529
# 6581   GGAL   USD     60min  2023-04-03 15:00:00  9.7386  9.7816  9.6529
# 6582   GGAL   USD     60min  2023-04-03 16:00:00  9.7472  9.7472  9.7472
#
#        close    volume        k1h  ...  compra  venta  closeLong  closeShort  \
# 0     5.8034     100.0        NaN  ...   False  False      False       False
# 1     6.0832  114582.0        NaN  ...   False  False      False       False
# 2     5.7954  159266.0        NaN  ...   False  False      False       False
# 3     5.6835  242263.0        NaN  ...   False  False      False       False
# 4     5.8274  186504.0        NaN  ...   False  False      False       False
# ...      ...       ...        ...  ...     ...    ...        ...         ...
# 6578  9.5756   29258.0  35.345039  ...   False  False      False       False
# 6579  9.6700   48527.0  43.814248  ...   False  False      False       False
# 6580  9.7301   32877.0  53.958531  ...   False  False      False       False
# 6581  9.7558  143309.0  64.423364  ...   False  False      False       False
# 6582  9.7472   13155.0  69.770972  ...   False  False      False       False
#
#       entradaLongH  entradaShortH  oper  long  short   state
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
# ...            ...            ...   ...   ...    ...     ...
# 6578          True          False                     neutro
# 6579          True          False                     neutro
# 6580          True          False                     neutro
# 6581          True          False                     neutro
# 6582          True          False                     neutro
#
# [6583 rows x 27 columns]
