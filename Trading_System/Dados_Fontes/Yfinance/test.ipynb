# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.0 MB 3.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.3/3.0 MB 3.5 MB/s eta 0:00:01
#      ------------------------ --------------- 1.8/3.0 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.6/3.0 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 3.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
# ...

# %%
from datetime import date
import pandas as pd
from Alert import Alert 
import yfinance as yf
pd.options.mode.chained_assignment = None  # default='warn'

symbol = "GGAL"
period = "1h"

alert = Alert(symbol,period)

if (period == "1h"):
    df = yf.download(tickers=symbol, period='1d', interval=period)
else:
    df = yf.download(tickers=symbol, period='60d', interval=period)

display(df)
print(len(df))
df.index = df.index.tz_localize(None)
#df.to_excel("GGAL_1H_yf.xlsx")
# Out:
# C:\Users\scitr\AppData\Local\Temp\ipykernel_15500\889071751.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers=symbol, period='1d', interval=period)
# [*********************100%***********************]  1 of 1 completed
# Price                          Close       High        Low       Open  Volume
# Ticker                          GGAL       GGAL       GGAL       GGAL    GGAL
# Datetime
# 2025-06-23 13:30:00+00:00  51.830002  52.320000  50.660000  51.685001  351493
# 2025-06-23 14:30:00+00:00  51.610001  52.090000  51.509998  51.830002  174003
# 2025-06-23 15:30:00+00:00  51.139999  51.564999  51.099998  51.529999  120909
# 2025-06-23 16:30:00+00:00  50.669998  51.189999  50.430000  51.115002  227319
# 2025-06-23 17:30:00+00:00  50.250099  50.900002  50.070000  50.669998  204695
# 2025-06-23 18:30:00+00:00  50.305000  50.593201  50.189999  50.244999  173009
# ...

# %%
GGAL = yf.Ticker('GGAL')
info = GGAL.fast_info.toJSON()
print (info)
# Out:
# {
#     "currency": "USD",
#     "dayHigh": 52.31999969482422,
#     "dayLow": 50.06999969482422,
#     "exchange": "NCM",
#     "fiftyDayAverage": 58.75919982910156,
#     "lastPrice": 50.369998931884766,
#     "lastVolume": 1576003,
#     "marketCap": 6674175968.471527,
#     "open": 51.685001373291016,
#     "previousClose": 52.0,
#     "quoteType": "EQUITY",
#     "regularMarketPreviousClose": 52.0,
#     "shares": 132503000,
#     "tenDayAverageVolume": 1945390,
#     "threeMonthAverageVolume": 1434563,
#     "timezone": "America/New_York",
#     "twoHundredDayAverage": 56.833000087738036,
#     "yearChange": 0.6149067940349036,
#     "yearHigh": 74.0,
#     "yearLow": 23.530000686645508
# }

# %%
GGAL = yf.Ticker('GGAL')
df = GGAL.history(start = '2025-01-01' , end = '2025-06-23')
display(df)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2025