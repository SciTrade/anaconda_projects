# %% [markdown]
# Conecta api do alphavantage extrae historico de titulo e inserta no BD

# %% [markdown]
# parametros da api

# %%
function = 'TIME_SERIES_INTRADAY'
symbol = 'GGAL'
interval = '60min'
month = '2009-02' 
apikey = 'BSFBG5DHV3CCXVMV'

# %%
import requests
import pandas as pd

# Construindo a URL dinamicamente
url = f'https://www.alphavantage.co/query?function={function}&symbol={symbol}&interval={interval}&month={month}&outputsize=full&apikey={apikey}'
r = requests.get(url)
data = r.json()

# Extraindo os dados do JSON
time_series = data.get(f'Time Series ({interval})', {})

# Convertendo para um dataframe do pandas
df = pd.DataFrame.from_dict(time_series, orient='index')

# Renomeando colunas para algo mais intuitivo
df.columns = ['Open', 'High', 'Low', 'Close', 'Volume']

# Adicionando a coluna DateTime como string
df.insert(0, 'DateTime', df.index.astype(str))

# Convertendo as colunas numéricas para float
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].astype(float)

# Exibindo o dataframe
display(df)
display(df.dtypes)
# Out:
#                                 DateTime    Open    High     Low   Close  \
# 2009-02-27 16:00:00  2009-02-27 16:00:00  1.4993  1.4993  1.4838  1.4993
# 2009-02-27 15:00:00  2009-02-27 15:00:00  1.3370  1.3602  1.2674  1.3292
# 2009-02-27 14:00:00  2009-02-27 14:00:00  1.3756  1.3833  1.3370  1.3524
# 2009-02-27 13:00:00  2009-02-27 13:00:00  1.3524  1.3756  1.3370  1.3679
# 2009-02-27 12:00:00  2009-02-27 12:00:00  1.3602  1.3602  1.3138  1.3524
# ...                                  ...     ...     ...     ...     ...
# 2009-02-03 14:00:00  2009-02-03 14:00:00  1.5456  1.5534  1.5456  1.5456
# 2009-02-03 13:00:00  2009-02-03 13:00:00  1.5688  1.5688  1.5456  1.5456
# 2009-02-02 15:00:00  2009-02-02 15:00:00  1.4915  1.5302  1.4915  1.5302
# 2009-02-02 10:00:00  2009-02-02 10:00:00  1.5070  1.5070  1.4761  1.4761
# 2009-02-02 09:00:00  2009-02-02 09:00:00  1.4065  1.4065  1.4065  1.4065
#
#                       Volume
# 2009-02-27 16:00:00   6700.0
# 2009-02-27 15:00:00  49206.0
# 2009-02-27 14:00:00  44994.0
# 2009-02-27 13:00:00  55020.0
# 2009-02-27 12:00:00  37724.0
# ...                      ...
# 2009-02-03 14:00:00   1200.0
# 2009-02-03 13:00:00   2600.0
# 2009-02-02 15:00:00   1100.0
# 2009-02-02 10:00:00   6500.0
# 2009-02-02 09:00:00    100.0
#
# [116 rows x 6 columns]
# DateTime     object
# Open        float64
# High        float64
# Low         float64
# Close       float64
# Volume      float64
# dtype: object
